# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import HTML
from wordcloud import WordCloud
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2}'.format
df = pd.read_csv('movies_complete.csv', parse_dates=['release_date'])
print("Top 5 row of movie data set:")
display(df.head())
print("Information of data frame:")
df.info()
#Access to a specific column:
print(df.genres[0])
print("\n"+df['cast'][0])
#get description of data frame
display(df.describe())
#checking the histogram for data frame to see the data distribution
display(df.hist(figsize=(20, 12), bins= 100))
#checking the top 10 information of a specific value
print(df['budget_musd'].head(10))
#get the most repeated data in dataframe's specific columns
print(df['budget_musd'].value_counts(dropna=False).head(20))
print(df['revenue_musd'].value_counts(dropna=False).head(20))
print(df['vote_average'].value_counts(dropna=False).head(20))
display(df.describe(include='object'))
display(df[df['title']=='Cinderella'])
# Creating a new data frame by required column of df for 
#next step to choose best and worst movies
df_best=df[['poster_path','title','budget_musd','revenue_musd','vote_count','vote_average','popularity']].copy()
#display(df_best.head())
df_best['profit_musd']=df_best['budget_musd'].sub(df['revenue_musd'])
df_best['return']=df_best['revenue_musd'].div(df['budget_musd'])
#display(df_best)
df_best.columns=['','Title','Budget','Revenue','Votes','Average Rating','Popularity','Profit','ROI']
#display(df_best)
df_best.set_index('Title',inplace=True)
#display(df_best)
#print(df_best.iloc[0,0])
subset=df_best.iloc[:5,:2]
#display(subset)
#display(HTML(subset.to_html(escape=False)))
df_best.sort_values(by='Average Rating',ascending=True)
df_best.sort_values(by='ROI',ascending=False)
df_best.loc[df_best['Budget']>=5].sort_values(by='ROI',ascending=False)
#df_best.info()
#df_best['Budget']=df_best['Budget'].fillna(0, inplace=True)
#df_best['Votes']=df_best['Votes'].fillna(0, inplace= True)
#df_best.info()
mask_genres=df['genres'].str.contains('Action')&df['genres'].str.contains('Science Fiction')
mask_genres
mask_actors=df['cast'].str.contains('Bruce Willis')
mask_actors
bruce=df.loc[mask_genres&mask_actors,['poster_path','title','vote_average']].sort_values(by='vote_average',ascending=False)
HTML(bruce.to_html(escape=False))
mask_director = df['director'] == 'Quentin Tarantino'
mask_actor = df['cast'].str.contains('Uma Thurman')
quentin=df.loc[mask_director&mask_actor,['poster_path','title','runtime']].sort_values(by='runtime').set_index('title')
HTML(quentin.to_html(escape=False))
df['production_companies']
mask_studio=df['production_companies'].str.contains('Pixar').fillna(False)
mask_time=df['release_date'].between('2010-01-01','2015-12-31')
pixar=df.loc[mask_studio & mask_time,['title','poster_path','revenue_musd','release_date']].sort_values(by ='revenue_musd', ascending=False)
HTML(pixar.to_html(escape=False))
mask_genres=df['genres'].str.contains('Action') | df['genres'].str.contains('Thriller')
mask_lan=df['original_language']=='en'
mask_vote=df['vote_average']>=7.5
mask_vote_count=df['vote_count']>=10
next_movie=df.loc[mask_genres & mask_lan & mask_vote & mask_vote_count,['title','poster_path','genres','vote_average','vote_count','release_date']].sort_values(by='release_date',ascending=False).set_index('title').head(20)
HTML(next_movie.to_html(escape=False))
df['tagline'][1]
df['overview'][1]
title=df['title'].dropna()
overview=df['overview'].dropna()
tagline=df['tagline'].dropna()
''.join(title)

title_corpus=" ".join(title)
overview_corpus=" ".join(overview)
tagline_corpus=" ".join(tagline)
tagline_corpus
title_wordcloud=WordCloud(background_color='white',height=2000,width=4000,max_words=300).generate(title_corpus)
title_wordcloud
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# Top 5 row of movie data set:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# ...

# %% [markdown]
# # Assistant
# The error you're encountering, `ModuleNotFoundError: No module named 'wordcloud'`, indicates that the Python environment you're using does not have the `wordcloud` library installed. This library is necessary for creating word clouds in your code.
#
# To fix this error, you need to install the `wordcloud` library. You can do this using pip.
#
# Would you like me to provide the command to install the library?

# %% [markdown]
# # User
# yes

# %% [markdown]
# # Assistant
# You can install the `wordcloud` library by running the following command in your terminal or command prompt:

# %% [markdown]
# bash
# pip install wordcloud

# %% [markdown]
# If you're using Jupyter Notebook, you can also run the following command in a code cell:

# %%
# !pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    ----- -------------------------------- 41.0/301.4 kB 245.8 kB/s eta 0:00:02
#    --------------------- --------------- 174.1/301.4 kB 952.6 kB/s eta 0:00:01
#    --------------------------------------  297.0/301.4 kB 1.5 MB/s eta 0:00:01
#    --------------------------------------- 301.4/301.4 kB 1.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# After running this command, the `wordcloud` library should be installed, and you should be able to run your code without encountering the `ModuleNotFoundError`.
